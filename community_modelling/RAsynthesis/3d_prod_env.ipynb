# %% [markdown]
# # Mixed substrate triculture

# %%
import pandas as pd
df = pd.read_csv("results/prod_env_yields_tri_xyl_glc_new_params.csv")

# %%
import pandas as pd
import plotly.express as px

fig = px.scatter_3d(df, x='time', y='biomass', z='RA', color='yield_factor')

marker_size = 4  # Adjust the size of the scatter points as needed

fig.update_traces(marker=dict(size=marker_size))

# Customize the layout and set the width and height of the figure
fig.update_layout(
    width=850,  # Set the width of the figure in pixels
    height=800    # Set the height of the figure in pixels
)

#fig.write_image("results/figures/call11_sal11_mam3/yield_envelope.svg")

# Show the plot
fig.show()

# %%
df.loc[df["RA"].idxmax()]
# Out:
# biomass          0.123012
# RA               0.165274
# time            41.200000
# yield_factor     3.100000
# Name: 4018, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fig, ax =plt.subplots(1,2, figsize=(12, 4))
sns.lineplot(data=df, x="time", y="biomass", hue="yield_factor", ax=ax[0], palette="flare")
sns.lineplot(data=df, x="time", y="RA", hue="yield_factor", ax=ax[1], legend=False, palette="flare")

# Add labels, legends, etc. if needed
ax[0].set_xlabel('Time')
ax[0].set_ylabel('Biomass (gDW)')
ax[1].set_xlabel('Time')
ax[1].set_ylabel('RA produced (mmol)')
ax[0].legend(title='production yield factor')
#plt.savefig('results/figures/call11_sal11_mam3/yield_envelope_2D.svg', format='svg')
#ax[1].legend(title='production yield factor')

# %%
import numpy as np

np.array([0.118, 0.0431, 0.223])*3.1
# Out:
# array([0.3658 , 0.13361, 0.6913 ])

# %% [markdown]
# # Glucose triculture

# %%
import pandas as pd
df = pd.read_csv("results/prod_env_yields_glc.csv")
df = df.rename({"0": "biomass", "1": "RA", "2": "time","3": "yield_factor"}, axis=1)

# %%
import pandas as pd
import plotly.express as px

fig = px.scatter_3d(df, x='time', y='biomass', z='RA', color='yield_factor')

marker_size = 4  # Adjust the size of the scatter points as needed

fig.update_traces(marker=dict(size=marker_size))

# Customize the layout and set the width and height of the figure
fig.update_layout(
    width=850,  # Set the width of the figure in pixels
    height=800    # Set the height of the figure in pixels
)

#fig.write_image("results/figures/call11_sal11_mam3/yield_envelope.svg")

# Show the plot
fig.show()

# %%
df.loc[df["RA"].idxmax()]
# Out:
# biomass          0.134894
# RA               0.147059
# time            28.900000
# yield_factor     6.100000
# Name: 9307, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fig, ax =plt.subplots(1,2, figsize=(12, 4))
sns.lineplot(data=df, x="time", y="biomass", hue="yield_factor", ax=ax[0], palette="flare")
sns.lineplot(data=df, x="time", y="RA", hue="yield_factor", ax=ax[1], legend=False, palette="flare")

# Add labels, legends, etc. if needed
ax[0].set_xlabel('Time')
ax[0].set_ylabel('Biomass (gDW)')
ax[1].set_xlabel('Time')
ax[1].set_ylabel('RA produced (mmol)')
ax[0].legend(title='production yield factor')
#plt.savefig('results/figures/call11_sal11_mam3/yield_envelope_2D.svg', format='svg')
#ax[1].legend(title='production yield factor')

# %% [markdown]
# # Co-culture

# %%
import pandas as pd
df = pd.read_csv("results/prod_env_yields_coculture.csv")
df = df.rename({"0": "biomass", "1": "RA", "2": "time","3": "yield_factor"}, axis=1)

# %%
import pandas as pd
import plotly.express as px

fig = px.scatter_3d(df, x='time', y='biomass', z='RA', color='yield_factor')

marker_size = 4  # Adjust the size of the scatter points as needed

fig.update_traces(marker=dict(size=marker_size))

# Customize the layout and set the width and height of the figure
fig.update_layout(
    width=850,  # Set the width of the figure in pixels
    height=800    # Set the height of the figure in pixels
)

#fig.write_image("results/figures/call11_sal11_mam3/yield_envelope.svg")

# Show the plot
fig.show()

# %%
df.loc[df["RA"].idxmax()]
# Out:
# biomass          0.107010
# RA               0.021296
# time            23.100000
# yield_factor     9.400000
# Name: 7927, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fig, ax =plt.subplots(1,2, figsize=(12, 4))
sns.lineplot(data=df, x="time", y="biomass", hue="yield_factor", ax=ax[0], palette="flare")
sns.lineplot(data=df, x="time", y="RA", hue="yield_factor", ax=ax[1], legend=False, palette="flare")

# Add labels, legends, etc. if needed
ax[0].set_xlabel('Time')
ax[0].set_ylabel('Biomass (gDW)')
ax[1].set_xlabel('Time')
ax[1].set_ylabel('RA produced (mmol)')
ax[0].legend(title='production yield factor')
#plt.savefig('results/figures/call11_sal11_mam3/yield_envelope_2D.svg', format='svg')
#ax[1].legend(title='production yield factor')
