# %%
from cobra import Model, Reaction, Metabolite
from cobra.io import read_sbml_model

# %%
# read models
clostridium = read_sbml_model('../GEMs/clostridium_acetobutylicum_NJ4.xml')
thermobac = read_sbml_model('../GEMs/thermoanaerobacterium_thermosaccharolyticum_M5.xml')

# %%
#description of model contentes
n_reactions = len(clostridium.reactions)
n_metabolites = len(clostridium.metabolites)
n_genes = len(clostridium.genes)

# %%
clostridium.reactions.EX_o2_e.upper_bound=0
clostridium.reactions.EX_o2_e.lower_bound=0

# %%
clostridium.reactions.get_by_id('EX_o2_e')
# Out:
# <Reaction EX_o2_e at 0x122987be0>

# %%
clostridium.summary()
# Out:
# <h3>Objective</h3><p>1.0 Growth = 46.64552696610923</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>3amp_e</td>
#       <td>EX_3amp_e</td>
#       <td>9.53</td>
#       <td>10</td>
#       <td>0.57%</td>
#     </tr>
#     <tr>
#       <td>3cmp_e</td>
#       <td>EX_3cmp_e</td>
#       <td>23.54</td>
#       <td>9</td>
#       <td>1.27%</td>
#     </tr>
#     <tr>
#       <td>akg_e</td>
#       <td>EX_akg_e</td>
#       <td>171.8</td>
#       <td>5</td>
#       <td>5.15%</td>
#     </tr>
#     <tr>
#       <td>arbt_e</td>
#       <td>EX_arbt_e</td>
#       <td>103.2</td>
#       <td>12</td>
#       <td>7.42%</td>
#     </tr>
#     <tr>
#       <td>arg__L_e</td>
#       <td>EX_arg__L_e</td>
#       <td>50.03</td>
#       <td>6</td>
# ...

# %%
from reframed import load_cbmodel
thermobac_model = load_cbmodel('../GEMs/thermoanaerobacterium_thermosaccharolyticum_M5.xml', flavor='fbc2')

# %%
thermobac_model.summary()
# Out:
# Metabolites:
# C_c 809
# C_e 250
# C_p 177
#
# Reactions:
# enzymatic 827
# transport 528
# exchange 247
# sink 0
# other 214
