# %%
from cobra.io import read_sbml_model
from utils import model_validation as mv

iJL432 = read_sbml_model('GEMs/iJL432.xml')
iCAC802 = read_sbml_model('GEMs/iCAC802.xml')
# Out:
# Model does not contain SBML fbc package information.
# '' is not a valid SBML 'SId'.
# SBML package 'layout' not supported by cobrapy, information is not parsed
# SBML package 'render' not supported by cobrapy, information is not parsed
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0001 "ala-L + glx <==> pyr + gly">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0001 "ala-L + glx <==> pyr + gly">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0002 "pyr + ser-L <==> ala-L + hpyr">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0002 "pyr + ser-L <==> ala-L + hpyr">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0004 "nad + 3pg <==> nadh + (1) h + 3php">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0004 "nad + 3pg <==> nadh + (1) h + 3php">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0006 "nadph + 4pasp --> nadp + pi + aspsa">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0006 "nadph + 4pasp --> nadp + pi + aspsa">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0009 "h2o + h + dctp --> nh4 + dutp">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0009 "h2o + h + dctp --> nh4 + dutp">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0010 "h2o + ctp + h --> nh4 + utp">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0010 "h2o + ctp + h --> nh4 + utp">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0012 "prpp + orot --> ppi + orot5p">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0012 "prpp + orot --> ppi + orot5p">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0013 "nadph + o2 + h + 2oph --> h2o + nadp + 2ohph">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0013 "nadph + o2 + h + 2oph --> h2o + nadp + 2ohph">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0014 "zn2 + h[e] + k[e] <==> zn2[e] + h + k">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0014 "zn2 + h[e] + k[e] <==> zn2[e] + h + k">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0015 "h[e] + k[e] + cd2 <==> h + k + cd2[e]">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0015 "h[e] + k[e] + cd2 <==> h + k + cd2[e]">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0016 "h2o + met-L + trdox <==> metox + trdrd">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0016 "h2o + met-L + trdox <==> metox + trdrd">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0022 "nadph + h + alac-S <==> nadp + 23dhmb">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0022 "nadph + h + alac-S <==> nadp + 23dhmb">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0023 "2ahbut <==> (R)-3-Hydroxy-3-methyl-2-oxopentanoate">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0023 "2ahbut <==> (R)-3-Hydroxy-3-methyl-2-oxopentanoate">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0024 "nadp + 23dhmp <==> nadph + h + (R)-3-Hydroxy-3-methyl-2-oxopentanoate">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0024 "nadp + 23dhmp <==> nadph + h + (R)-3-Hydroxy-3-methyl-2-oxopentanoate">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0025 "alac-S <==> 33hmeoxobut">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0025 "alac-S <==> 33hmeoxobut">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0026 "nadp + 23dhmb <==> nadph + h + 33hmeoxobut">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0026 "nadp + 23dhmb <==> nadph + h + 33hmeoxobut">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0027 "(8) h + no2 + (3) fdxrd --> (2) h2o + nh4 + (3) fdxox">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0027 "(8) h + no2 + (3) fdxrd --> (2) h2o + nh4 + (3) fdxox">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0028 "(3) h2o + h2s + (3) fdxox <==> (7) h + so3 + (3) fdxrd">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0028 "(3) h2o + h2s + (3) fdxox <==> (7) h + so3 + (3) fdxrd">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0029 "nadph + h + glutrna <==> nadp + glu1sa + trnaglu">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0029 "nadph + h + glutrna <==> nadp + glu1sa + trnaglu">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0030 "(2) h + sheme <==> scl + fe2">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0030 "(2) h + sheme <==> scl + fe2">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0031 "nad + pre2 <==> nadh + h + scl">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0031 "nad + pre2 <==> nadh + h + scl">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0032 "h2o + (4) ppbng --> (4) nh4 + hmbil">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0032 "h2o + (4) ppbng --> (4) nh4 + hmbil">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0033 "hmbil <==> h2o + uppg3">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0033 "hmbil <==> h2o + uppg3">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0034 "(2) amet + uppg3 <==> (2) ahcys + (2) h + pre2">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0034 "(2) amet + uppg3 <==> (2) ahcys + (2) h + pre2">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0035 "5aop <==> glu1sa">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0035 "5aop <==> glu1sa">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0036 "(2) 5aop --> (2) h2o + h + ppbng">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0036 "(2) 5aop --> (2) h2o + h + ppbng">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0037 "tsul + achms + trdrd <==> ac + so3 + hcys-L + trdox">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0037 "tsul + achms + trdrd <==> ac + so3 + hcys-L + trdox">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0040 "atp + Adenylylselenate <==> adp + (1) h + 3-Phosphoadenylylselenate">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0040 "atp + Adenylylselenate <==> adp + (1) h + 3-Phosphoadenylylselenate">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0041 "atp + aps <==> adp + paps">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0041 "atp + aps <==> adp + paps">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0043 "amp + (2) ficytc + Selenite <==> (2) focytc + Adenylylselenate + (2) h">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0043 "amp + (2) ficytc + Selenite <==> (2) focytc + Adenylylselenate + (2) h">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0045 "fad + amp + so3 <==> aps + fadh2">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0045 "fad + amp + so3 <==> aps + fadh2">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0047 "atp + so4 + h <==> ppi + aps">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0047 "atp + so4 + h <==> ppi + aps">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0048 "h2o + atp + gtp + so4 <==> pi + ppi + gdp + aps">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0048 "h2o + atp + gtp + so4 <==> pi + ppi + gdp + aps">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0050 "h2o + atp + gln-L[e] --> adp + pi + gln-L + (1) h">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0050 "h2o + atp + gln-L[e] --> adp + pi + gln-L + (1) h">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0051 "h + mnl + Protein N-pros-phosphohistidine <==> mnl1p + Protein histidine">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0051 "h + mnl + Protein N-pros-phosphohistidine <==> mnl1p + Protein histidine">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0053 "pep + mnl[e] <==> pyr + mnl1p">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0053 "pep + mnl[e] <==> pyr + mnl1p">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0055 "nad + mnl1p <==> nadh + h + f6p">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0055 "nad + mnl1p <==> nadh + h + f6p">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0057 "gln-L + f6p <==> glu-L + gam6p">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0057 "gln-L + f6p <==> glu-L + gam6p">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0059 "h2o + acmum6p <==> lac-D + acgam6p">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0059 "h2o + acmum6p <==> lac-D + acgam6p">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0061 "h2o + chitob <==> (2) acgam">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0061 "h2o + chitob <==> (2) acgam">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0063 "h2o + gam6p --> nh4 + f6p">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0063 "h2o + gam6p --> nh4 + f6p">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0065 "h2o + acgam6p <==> ac + gam6p">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0065 "h2o + acgam6p <==> ac + gam6p">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0066 "amet + s + dtbt --> met-L + h + btn + dad-5">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0066 "amet + s + dtbt --> met-L + h + btn + dad-5">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0067 "ppi + btamp --> atp + h + btn">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0067 "ppi + btamp --> atp + h + btn">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0069 "h + pphn --> h2o + co2 + phpyr">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0069 "h + pphn --> h2o + co2 + phpyr">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0072 "h + fru + Protein N-pros-phosphohistidine <==> f1p + Protein histidine">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0072 "h + fru + Protein N-pros-phosphohistidine <==> f1p + Protein histidine">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0073 "pep + fru[e] <==> pyr + f1p">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0073 "pep + fru[e] <==> pyr + f1p">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0075 "h2o + atp + mobd[e] --> adp + pi + h + mobd">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0075 "h2o + atp + mobd[e] --> adp + pi + h + mobd">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0077 "(16) h2o + (16) atp + n2 + (8) fdxrd <==> (16) adp + (16) pi + (2) nh4 + (6) h + (8) fdxox + h2">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0077 "(16) h2o + (16) atp + n2 + (8) fdxrd <==> (16) adp + (16) pi + (2) nh4 + (6) h + (8) fdxox + h2">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0078 "h2o + accoa + akg <==> coa + (1) h + hcit">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0078 "h2o + accoa + akg <==> coa + (1) h + hcit">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0084 "h2o + h + gua --> nh4 + xan">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0084 "h2o + h + gua --> nh4 + xan">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0085 "nad + 5mthf <==> nadh + h + mlthf">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0085 "nad + 5mthf <==> nadh + h + mlthf">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0086 "nadp + 5mthf <==> nadph + h + mlthf">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0086 "nadp + 5mthf <==> nadph + h + mlthf">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0088 "orn + cbp --> pi + (2) h + citr-L">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0088 "orn + cbp --> pi + (2) h + citr-L">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0089 "h2o + 23camp <==> 3amp">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0089 "h2o + 23camp <==> 3amp">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0090 "h2o + 23cgmp <==> 3gmp">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0090 "h2o + 23cgmp <==> 3gmp">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0091 "h2o + 23cump <==>  3ump">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0091 "h2o + 23cump <==>  3ump">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0092 "h2o + 23ccmp <==> 3cmp">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0092 "h2o + 23ccmp <==> 3cmp">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0093 "nad + 2ddglcn <==> nadh + h + 46dh25dohxn">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0093 "nad + 2ddglcn <==> nadh + h + 46dh25dohxn">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0095 "akg + ala-B <==> glu-L  + msa">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0095 "akg + ala-B <==> glu-L  + msa">
# Uppercase AND/OR found in rule 'CAC0368 AND CAC1427'.
# invalid syntax
# /Users/andreastallvik/Projects/BIOTBT3900/venv/lib/python3.10/site-packages/cobra/core/gene.py:358: SyntaxWarning: Uppercase AND/OR found in rule 'CAC0368 AND CAC1427'.
#   warn(
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0096 "h2o + NG,NG-Dimethyl-L-arginine --> citr-L + dma">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0096 "h2o + NG,NG-Dimethyl-L-arginine --> citr-L + dma">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0097 "h2o + atp + cellb[e] --> adp + pi + (1) h + cellb">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0097 "h2o + atp + cellb[e] --> adp + pi + (1) h + cellb">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0098 "pep + cellb[e] <==> pyr + 6pgg">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0098 "pep + cellb[e] <==> pyr + 6pgg">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0099 "h + succ + Cystathionine <==> cys-L + suchms">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0099 "h + succ + Cystathionine <==> cys-L + suchms">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0100 "cys-L + achms <==> ac + Cystathionine + h">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0100 "cys-L + achms <==> ac + Cystathionine + h">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0101 "h2o + suchms --> nh4 + succ + h + 2obut">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0101 "h2o + suchms --> nh4 + succ + h + 2obut">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0106 "h2o + Cystathionine --> nh4 + pyr + hcys-L">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0106 "h2o + Cystathionine --> nh4 + pyr + hcys-L">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0110 "fald + ru5p-D <==> D-arabino-6-Phospho-hex-3-ulose">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0110 "fald + ru5p-D <==> D-arabino-6-Phospho-hex-3-ulose">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0112 "D-arabino-6-Phospho-hex-3-ulose <==> f6p">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0112 "D-arabino-6-Phospho-hex-3-ulose <==> f6p">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0114 "h2o + 2pglyc --> pi + h + glyclt">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0114 "h2o + 2pglyc --> pi + h + glyclt">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0116 "pep + sucr[e] <==> pyr + suc6p">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0116 "pep + sucr[e] <==> pyr + suc6p">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0119 "h2o + stchs <==> fru + Manninotriose">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0119 "h2o + stchs <==> fru + Manninotriose">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0120 "h2o + sucr <==> glc-D + fru">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0120 "h2o + sucr <==> glc-D + fru">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0122 "h2o + raffin <==> fru + melib">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0122 "h2o + raffin <==> fru + melib">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0123 "h2o + suc6p <==> g6p + fru">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0123 "h2o + suc6p <==> g6p + fru">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0126 "2p4c2me <==> cmp + 2mecdp">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0126 "2p4c2me <==> cmp + 2mecdp">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0127 "cl[e] <==> cl">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0127 "cl[e] <==> cl">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0130 "ctp + trdrd --> h2o + trdox + dctp">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0130 "ctp + trdrd --> h2o + trdox + dctp">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0131 "utp + trdrd --> h2o + trdox + dutp">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0131 "utp + trdrd --> h2o + trdox + dutp">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0133 "gam1p <==> gam6p">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0133 "gam1p <==> gam6p">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0135 "coa + apoACP <==> pap + ACP">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0135 "coa + apoACP <==> pap + ACP">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0139 "nadph + h + uaccg --> nadp + uamr">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0139 "nadph + h + uaccg --> nadp + uamr">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0140 "--> dnarep">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0140 "--> dnarep">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0142 "ctp + tag6p-D -->  cdp + tagdp-D">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0142 "ctp + tag6p-D -->  cdp + tagdp-D">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0143 "utp + tag6p-D --> udp  + tagdp-D">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0143 "utp + tag6p-D --> udp  + tagdp-D">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0144 "itp + tag6p-D -->  idp + tagdp-D">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0144 "itp + tag6p-D -->  idp + tagdp-D">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0145 "atp + s7p <==> adp + s17bp">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0145 "atp + s7p <==> adp + s17bp">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0146 "atp + f6p <==> adp + fdp">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0146 "atp + f6p <==> adp + fdp">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0148 "gdp + pep  --> pyr + gtp">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0148 "gdp + pep  --> pyr + gtp">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0149 "pep  + dadp --> pyr + datp">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0149 "pep  + dadp --> pyr + datp">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0150 "pep  + dgdp --> pyr + dgtp">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0150 "pep  + dgdp --> pyr + dgtp">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0152 "h2o + dhor-S <==> h + cbasp">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0152 "h2o + dhor-S <==> h + cbasp">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0153 "h + amet + 2dmmq8 <==> ahcys + mqn8">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0153 "h + amet + 2dmmq8 <==> ahcys + mqn8">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0154 "h + arbt + Protein N-pros-phosphohistidine <==> arbt6p + Protein histidine">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0154 "h + arbt + Protein N-pros-phosphohistidine <==> arbt6p + Protein histidine">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0155 "h2o + tre6p <==> glc-D + g6p">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0155 "h2o + tre6p <==> glc-D + g6p">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0158 "h2o + atp + pyr --> pi + amp + pep + h">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0158 "h2o + atp + pyr --> pi + amp + pep + h">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0159 "nadh + oaa + (1) h --> nad + mal-L">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0159 "nadh + oaa + (1) h --> nad + mal-L">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0160 "h + glc-D + Protein N-pros-phosphohistidine <==> g6p + Protein histidine">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0160 "h + glc-D + Protein N-pros-phosphohistidine <==> g6p + Protein histidine">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0161 "h + salcn + Protein N-pros-phosphohistidine <==> salc6p + Protein histidine">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0161 "h + salcn + Protein N-pros-phosphohistidine <==> salc6p + Protein histidine">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0163 "hcys-L + 5mthf <==> met-L + thf">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0163 "hcys-L + 5mthf <==> met-L + thf">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0165 "atp + appl + adcobhex <==> adp + pi + h + adocbi">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0165 "atp + appl + adcobhex <==> adp + pi + h + adocbi">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0166 "atp + applp + adcobhex <==> adp + pi + (2) h + adocbip">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0166 "atp + applp + adcobhex <==> adp + pi + (2) h + adocbip">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0167 "amet + codhpre6 <==> ahcys + h + Cobalt-precorrin 7">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0167 "amet + codhpre6 <==> ahcys + h + Cobalt-precorrin 7">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0170 "nadp + 5aprbu <==> nadph + h + 5apru">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0170 "nadp + 5aprbu <==> nadph + h + 5apru">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0171 "h2o + h + 25drapp --> nh4 + 5apru">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0171 "h2o + h + 25drapp --> nh4 + 5apru">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0172 "(2) dmlz --> ribflv + 4r5au">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0172 "(2) dmlz --> ribflv + 4r5au">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0176 "(3) h2o + gtp --> ppi + for + h + 25drapp">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0176 "(3) h2o + gtp --> ppi + for + h + 25drapp">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0177 "ru5p-D --> for + h + db4p">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0177 "ru5p-D --> for + h + db4p">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0178 "4r5au + db4p <==> (2) h2o + pi + h + dmlz">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0178 "4r5au + db4p <==> (2) h2o + pi + h + dmlz">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0179 "gln-L + g3p + ru5p-D --> (3) h2o + pi + pydx5p + glu-L + (2) h">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0179 "gln-L + g3p + ru5p-D --> (3) h2o + pi + pydx5p + glu-L + (2) h">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0182 "h + 26dap-M --> co2 + lys-L">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0182 "h + 26dap-M --> co2 + lys-L">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0183 "h2o + atp + no3[e] --> adp + pi + (1) h + no3">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0183 "h2o + atp + no3[e] --> adp + pi + (1) h + no3">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0184 "atp + (1) h + leu-L + trnaleu <==> ppi + amp + leutrna">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0184 "atp + (1) h + leu-L + trnaleu <==> ppi + amp + leutrna">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0185 "atp --> ppi + camp">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0185 "atp --> ppi + camp">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0190 "utp + uri <==> udp  + ump">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0190 "utp + uri <==> udp  + ump">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0192 "datp + Cytidine <==> cmp  + dadp">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0192 "datp + Cytidine <==> cmp  + dadp">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0193 "datp + uri <==>  ump + dadp">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0193 "datp + uri <==>  ump + dadp">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0194 "dgtp + uri <==>  ump + dgdp">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0194 "dgtp + uri <==>  ump + dgdp">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0195 "dgtp + Cytidine <==> cmp  + dgdp">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0195 "dgtp + Cytidine <==> cmp  + dgdp">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0196 "dttp + Cytidine <==> cmp  + dtdp">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0196 "dttp + Cytidine <==> cmp  + dtdp">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0197 "uri + dttp <==>  ump + dtdp">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0197 "uri + dttp <==>  ump + dtdp">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0198 "uri + dctp <==>  ump + dcdp">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0198 "uri + dctp <==>  ump + dcdp">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0199 "uri + dutp -->  ump + dudp">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0199 "uri + dutp -->  ump + dudp">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0200 "dctp + Cytidine <==> cmp  + dcdp">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0200 "dctp + Cytidine <==> cmp  + dcdp">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0201 "dutp + Cytidine --> cmp  + dudp">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0201 "dutp + Cytidine --> cmp  + dudp">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0202 "gtp + Cytidine <==> gdp + cmp">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0202 "gtp + Cytidine <==> gdp + cmp">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0203 "atp + uri <==> adp + ump">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0203 "atp + uri <==> adp + ump">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0204 "itp + uri <==> idp + ump">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0204 "itp + uri <==> idp + ump">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0205 "utp + Cytidine <==> udp + cmp">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0205 "utp + Cytidine <==> udp + cmp">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0206 "atp + Cytidine <==> adp + cmp">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0206 "atp + Cytidine <==> adp + cmp">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0207 "gtp + uri <==> gdp + ump">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0207 "gtp + uri <==> gdp + ump">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0209 "ser-L --> nh4 + pyr">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0209 "ser-L --> nh4 + pyr">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0210 "ser-L + cdpdtdecg --> cmp + h + ps140">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0210 "ser-L + cdpdtdecg --> cmp + h + ps140">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0211 "ser-L + CDP-1,2-dianteisoheptadecanoylglycerol --> cmp + h + Dianteisoheptadecanoylphosphatidylserine">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0211 "ser-L + CDP-1,2-dianteisoheptadecanoylglycerol --> cmp + h + Dianteisoheptadecanoylphosphatidylserine">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0212 "ser-L + CDP-1,2-dianteisopentadecanoylglycerol --> cmp + h + Dianteisopentadecanoylphosphatidylserine">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0212 "ser-L + CDP-1,2-dianteisopentadecanoylglycerol --> cmp + h + Dianteisopentadecanoylphosphatidylserine">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0213 "ser-L + cdpdtdec7eg --> cmp + h + ps141">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0213 "ser-L + cdpdtdec7eg --> cmp + h + ps141">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0214 "ser-L + CDP-1,2-diisotetradecanoylglycerol --> cmp + h + Diisotetradecanoylphosphatidylserine">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0214 "ser-L + CDP-1,2-diisotetradecanoylglycerol --> cmp + h + Diisotetradecanoylphosphatidylserine">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0215 "ser-L + cdpdhdecg --> cmp + h + ps160">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0215 "ser-L + cdpdhdecg --> cmp + h + ps160">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0216 "ser-L + cdpdodec11eg --> cmp + h + ps181">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0216 "ser-L + cdpdodec11eg --> cmp + h + ps181">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0217 "ser-L + cdpdodecg --> cmp + h + ps180">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0217 "ser-L + cdpdodecg --> cmp + h + ps180">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0218 "ser-L + cdpdhdec9eg --> cmp + h + ps161">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0218 "ser-L + cdpdhdec9eg --> cmp + h + ps161">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0219 "ser-L + CDP-1,2-diisohexadecanoylglycerol --> cmp + h + Diisohexadecanoylphosphatidylserine">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0219 "ser-L + CDP-1,2-diisohexadecanoylglycerol --> cmp + h + Diisohexadecanoylphosphatidylserine">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0220 "ser-L + CDP-1,2-diisoheptadecanoylglycerol --> cmp + h + Diisoheptadecanoylphosphatidylserine">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0220 "ser-L + CDP-1,2-diisoheptadecanoylglycerol --> cmp + h + Diisoheptadecanoylphosphatidylserine">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0221 "ser-L + CDP-1,2-diisopentadecanoylglycerol --> cmp + h + Diisopentadecanoylphosphatidylserine">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0221 "ser-L + CDP-1,2-diisopentadecanoylglycerol --> cmp + h + Diisopentadecanoylphosphatidylserine">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0222 "ser-L + cdpdddecg --> cmp + h + ps120">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0222 "ser-L + cdpdddecg --> cmp + h + ps120">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0223 "nh4[e] <==> nh4">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0223 "nh4[e] <==> nh4">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0225 "accoa + ser-L --> coa + acser">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0225 "accoa + ser-L --> coa + acser">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0228 "galur <==> tagur">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0228 "galur <==> tagur">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0229 "glcur <==> fruur">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0229 "glcur <==> fruur">
# Encoding LOWER_BOUND and UPPER_BOUND in KineticLaw is discouraged, use fbc:fluxBounds instead: <Reaction R_R0230 "h[e] + melib[e] <==> h + melib">
# Use of GENE ASSOCIATION or GENE_ASSOCIATION in the notes element is discouraged, use fbc:gpr instead: <Reaction R_R0230 "h[e] + melib[e] <==> h + melib">
# ...
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_R1781 "h2o + amet + pre5 <==> ahcys + ac + (2) h + pre6a">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_R1782 "atp + co1dam <==> pppi + adcobdam">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_R1783 "(2) amet + cpppg3 <==> (2) co2 + (2) met-L + pppg9 + (2) dad-5">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_R1784 "h2o + atp + cobalt2 + hgbam <==> adp + pi + (2) h + co2dam">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_R1785 "fmnh2 + (2) co2dam <==> fmn + (2) h + (2) co1dam">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_R1786 "12dag3p <==> pa120">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_R1787 "nad + nadph <==> nadh + nadp">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_R1788 "ppi + h2o --> (2) pi + (2) h">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_1 "h[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_2 "k[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_3 "zn2[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_4 "cd2[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_5 "gln-L[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_6 "mnl[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_7 "fru[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_8 "mobd[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_9 "mal-L[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_10 "cellb[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_11 "sucr[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_12 "glyc3p[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_13 "cl[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_14 "no3[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_15 "nh4[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_16 "melib[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_17 "na1[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_18 "glyc[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_19 "ferrich[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_20 "ptrc[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_21 "spmd[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_22 "xan[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_23 "cys-L[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_24 "met-L[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_25 "metox[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_26 "metox-R[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_27 "met-D[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_28 "fe2[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_29 "gal[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_30 "arab-L[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_31 "xyl-D[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_32 "acgam[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_33 "btn[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_34 "salcn[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_35 "arbt[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_36 "rib-D[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_37 "man[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_38 "ser-L[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_39 "gly[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_40 "ser-D[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_41 "ala-D[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_42 "pro-L[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_43 "for[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_44 "no2[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_45 "akg[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_46 "ile-L[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_47 "leu-L[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_48 "val-L[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_49 "pi[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_50 "glu-L[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_51 "galt[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_52 "gam[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_53 "acmana[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_54 "tre[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_55 "sbt-D[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_56 "mg2[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_57 "cobalt2[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_58 "ura[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_59 "thr-L[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_60 "met-L-ala-L[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_61 "gly-asp-L[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_62 "ala-L-leu-L[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_63 "gly-cys-L[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_64 "L-alagly[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_65 "gly-met-L[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_66 "Gly-Tyr[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_67 "ala-L-his-L[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_68 "gly-glu-L[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_69 "gly-leu-L[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_70 "ala-L-asp-L[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_71 "cgly[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_72 "gly-phe-L[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_73 "ala-L-Thr-L[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_74 "ala-L-glu-L[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_75 "gly-gln-L[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_76 "gly-pro-L[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_77 "gly-asn-L[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_78 "ala-L-gln-L[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_79 "Vitamin B12[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_80 "cbl1[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_81 "cbl2[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_82 "lys-L[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_83 "etha[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_84 "hxan[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_85 "glcn[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_86 "ribflv[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_87 "glyb[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_88 "lcts[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_89 "mn2[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_90 "malt[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_91 "glc-D[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_92 "idon-L[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_93 "trp-L[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_94 "sprm[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_95 "cu2[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_96 "but[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_97 "so4[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_98 "ca2[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_99 "actn-R[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_100 "fe3[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_101 "h2o[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_102 "o2[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_103 "co2[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_104 "ac[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_105 "succ[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_106 "lac-L[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_107 "thm[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_108 "4abz[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_109 "urea[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_110 "acetone[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_111 "etoh[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_112 "n2[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_113 "n-Butanol[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_114 "trdrd[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_115 "fdxrd[e] <==>">
# Encoding OBJECTIVE_COEFFICIENT in KineticLaw is discouraged, use fbc:fluxObjective instead: <Reaction R_Ex_116 "h2[e] <==>      ">

# %%
nj4 = read_sbml_model('GEMs/NJ4_curated.xml')

# %% [markdown]
# # iCAC802 model
#
# namespace is not easy to navigate - but there is a corresponding excel doc. that can be used for some automated translation

# %%
iCAC802
# Out:
# <Model  at 0x124f75000>

# %% [markdown]
# iCAC802 actually has more metabolites and reactions than my nj4 model

# %%
prod_rx = [
    'Ex_113', #butanol
    'Ex_96', #butyrate
    'Ex_110', #acetone
    'Ex_111', #ethanol
    'Ex_104', #acetate
]

# %%
from utils import static_sim

static_sim.plot_flux_envelopes(iCAC802, reactions=prod_rx, BM_func='Biomass')

# %% [markdown]
# - at fist glance it looks like but/ac is growth coupled - but actually it looks as though it is just possible for the model to take them up? This seems to be describing the solventogenic phase (as acetone production is growth-coupled)
# - idea: look at acetone, butyrate uptake and growth at the same time!

# %%
import straindesign as sd
import matplotlib.pyplot as plt

_,_,plot = sd.plot_flux_space(iCAC802,('-Ex_96','Ex_110','Biomass'),points=10, show=False);
plot._axes.view_init(elev=20, azim=130)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [17], line 5
#       2 import matplotlib.pyplot as plt
#       4 #_,_,plot =
# ----> 5 sd.plot_flux_space(iCAC802,('-Ex_96','Ex_110','Biomass'),points=10, show=False);
#       6 # plot._axes.view_init(elev=20, azim=130)
#       7 # plt.show()
#
# File ~/Projects/BIOTBT3900/venv/lib/python3.10/site-packages/straindesign/lptools.py:914, in plot_flux_space(model, axes, **kwargs)
#     912 for i, (x, l, u) in enumerate(zip(x_space.copy(), lb, ub)):
#     913     if l != u:
# --> 914         y_space = linspace(l, u, int(-(-points // (max_diff_y / abs(l - u)))))
#     915     else:
#     916         y_space = [l]
#
# ValueError: cannot convert float NaN to integer

# %% [markdown]
# # iJL432
#
# namespace is difficult + there is only a pdf that does not lend to id / name translation

# %%
products = ['BUOH', 'BU', 'ACETONE', 'AC', 'ETOH']
prod_reactions = [str('EX_'+prod+'_Ext_') for prod in products]
# uptake rx: EX_DXYL_Ext_

# %%
from utils import static_sim

static_sim.plot_flux_envelopes(iJL432, reactions=prod_reactions, BM_func='EX_Biomass')
# Out:
# Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.

# %%
iJL432.reactions.EX_ETOH_Ext_
# Out:
# <Reaction EX_ETOH_Ext_ at 0x127621f60>

# %%
iJL432.reactions.EX_Biomass
# Out:
# <Reaction EX_Biomass at 0x12cc47a00>

# %%
iJL432.summary()
# Out:
# <h3>Objective</h3><p>1.0 EX_Biomass = 0.3287407019165052</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>GLC_Ext__Cell</td>
#       <td>EX_GLC_Ext_</td>
#       <td>10</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>NH3_Ext__Cell</td>
#       <td>EX_NH3_Ext_</td>
#       <td>2.585</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>PABA_Ext__Cell</td>
#       <td>EX_PABA_Ext_</td>
#       <td>0.005213</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>Pi_Ext__Cell</td>
#       <td>EX_Pi_Ext_</td>
#       <td>0.2976</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>SO4_Ext__Cell</td>
#       <td>EX_SO4_Ext_</td>
#       <td>0.3571</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>ACETONE_Ext__Cell</td>
#       <td>EX_ACETONE_Ext_</td>
#       <td>-0.287</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>AC_Ext__Cell</td>
#       <td>EX_AC_Ext_</td>
#       <td>-2.05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>BU_Ext__Cell</td>
#       <td>EX_BU_Ext_</td>
#       <td>-6.48</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>BIOMASS_Cell</td>
#       <td>EX_Biomass</td>
#       <td>-0.3287</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>CO2_Ext__Cell</td>
#       <td>EX_CO2_Ext_</td>
#       <td>-16.45</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>GLYCALD_Ext__Cell</td>
#       <td>EX_GLYCALD_Ext_</td>
#       <td>-0.005213</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>H2_Ext__Cell</td>
#       <td>EX_H2_Ext_</td>
#       <td>-16.41</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table>

# %%
essential_rxns = ['EX_PABA_Ext_', 'EX_SO4_Ext_', 'EX_NH3_Ext_', 'EX_Pi_Ext_', 'EX_DXYL_Ext_', 'EX_GLC_Ext_']

medium = {rx:0 for rx in iJL432.medium.keys()}

for rx in essential_rxns:
    medium[rx] = 10
# Out:
# Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.

# %%
with iJL432 as model:
    iJL432.medium = medium
    sol = iJL432.optimize()
# Out:
# Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.

# %%
sol
# Out:
# <Solution 0.329 at 0x128034ca0>

# %%
# set medium to be xylose minimal medium
# TODO

# %%
iJL432.reactions.rBIOMASS.metabolites
# Out:
# {<Metabolite ATP_Cell at 0x12098ca90>: -40.0,
#  <Metabolite CARBO_Cell at 0x12098d3c0>: -0.0432,
#  <Metabolite DNA_Cell at 0x12098f460>: -0.026,
#  <Metabolite PEPTIDO_Cell at 0x120949e70>: -0.1009,
#  <Metabolite PLIPID_Cell at 0x12098d5a0>: -0.076,
#  <Metabolite PROTEIN_Cell at 0x12098f1f0>: -0.5284,
#  <Metabolite RNA_Cell at 0x12094bb50>: -0.0655,
#  <Metabolite TEICH_Cell at 0x12094bc70>: -0.08,
#  <Metabolite TRACE_Cell at 0x12094b820>: -0.0494,
#  <Metabolite ADP_Cell at 0x12098c280>: 40.0,
#  <Metabolite BIOMASS_Cell at 0x12098d840>: 1.0,
#  <Metabolite Pi_Cell at 0x12098c460>: 40.0}

# %% [markdown]
# # compare to my NJ4 model

# %%
from utils import static_sim

prod_reactions = ["EX_but_e", "EX_ac_e", "EX_etoh_e", "EX_btoh_e", "EX_acetone_e"]

static_sim.plot_flux_envelopes(nj4, reactions=prod_reactions)
# Out:
# Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.

# %% [markdown]
# # Thermosaccralyticum model

# %%
from cobra.io import read_sbml_model
import pandas as pd

excel_model = pd.read_excel("GEMS/thermoanaerobe_sacc_2015.xls")

# %%
from utils import read_excel

thermo_model = read_excel.read_excel("GEMS/12918_2015_159_MOESM7_ESM.xls",
                          rxn_sheet_name="reactions",
                          rxn_id_key="Rxn name",
                          rxn_name_key="Rxn description",
                          rxn_str_key="Formula",
                          rxn_gpr_key="Gene-reaction association",
                          rxn_lb_key="LB",
                          rxn_ub_key="UB",
                          rxn_fwd_arrow="->",
                          rxn_rev_arrow="<-",
                          rxn_reversible_arrow="<=>",
                          met_sheet_name="metabolites",
                          met_id_key="Metabolite name",
                          met_name_key="Metabolite description",
                          met_formula_key="Metabolite charged formula",)
# Out:
# unknown metabolite 'fdox' created

# %%
thermo_model.objective = thermo_model.reactions.biomass_target

# %%
thermo_model.summary()
# Out:
# <h3>Objective</h3><p>1.0 biomass_target = 4.315766231539374</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>ca2[c]</td>
#       <td>EXCH_ca2_c</td>
#       <td>0.01381</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>coa[c]</td>
#       <td>EXCH_coa_c</td>
#       <td>0.1533</td>
#       <td>21</td>
#       <td>0.41%</td>
#     </tr>
#     <tr>
#       <td>fe3[e]</td>
#       <td>EXCH_fe3(e)</td>
#       <td>0.01467</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>glc-D[e]</td>
#       <td>EXCH_glc-D(e)</td>
#       <td>131</td>
#       <td>6</td>
#       <td>99.59%</td>
#     </tr>
#     <tr>
#       <td>h2s[e]</td>
#       <td>EXCH_h2s(e)</td>
#       <td>0.6427</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>k[c]</td>
#       <td>EXCH_k_c</td>
#       <td>3.048</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>mg2[e]</td>
#       <td>EXCH_mg2(e)</td>
#       <td>0.4389</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>nh4[e]</td>
#       <td>EXCH_nh4(e)</td>
#       <td>41.78</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>pi[c]</td>
#       <td>EXCH_pi_c</td>
#       <td>10.08</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>ac[e]</td>
#       <td>EXCH_ac(e)</td>
#       <td>-202.8</td>
#       <td>2</td>
#       <td>66.95%</td>
#     </tr>
#     <tr>
#       <td>biomass[c]</td>
#       <td>EXCH_biomass_c</td>
#       <td>-4.316</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>co2[e]</td>
#       <td>EXCH_co2(e)</td>
#       <td>-200.3</td>
#       <td>1</td>
#       <td>33.05%</td>
#     </tr>
#     <tr>
#       <td>h2[e]</td>
#       <td>EXCH_h2(e)</td>
#       <td>-154.6</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>h2o[e]</td>
#       <td>EXCH_h2o(e)</td>
#       <td>-548</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table>
