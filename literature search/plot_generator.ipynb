# %% [markdown]
# notebook to look at plots:)
# TODO: put all plots here with an explanitory sentance

# %%
import pandas as pd
import plotting

df1 = pd.read_csv("all_articles.csv")
df2 = pd.read_csv("defined_articles.csv")

# %%
plotting.publications_per_year(df1)

# %%
plotting.substrate_hist(df2)

# %%
plotting.product_hist(df2)

# %%
plotting.stacked_publications_hist(df1)

# %%
plotting.species_hist(df2, 17)

# %%
plotting.genus_hist(df2, 14)

# %%
plotting.sankey_genus(df2)
